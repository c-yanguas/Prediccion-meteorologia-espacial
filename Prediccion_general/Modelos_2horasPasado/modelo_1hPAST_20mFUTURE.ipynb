# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import datetime

def obtener_tiempo(dfr):
    #Esta funcion permite obtener una columna Datetime a partir del agno, dia, hora y minuto de los datos iniciales
    dfr['Day'] = pd.to_datetime(dfr['Day'], format='%j').dt.strftime('%m-%d')
    dfr['Hour'] = dfr['Hour'].astype(str).str.zfill(2)
    dfr['Datetime'] = pd.to_datetime(dfr[['Year','Day', 'Hour', 'Minute']]
                   .astype(str).apply(' '.join, 1), format='%Y %m-%d %H %M') 
    return dfr

def sustituir(dfr):
    #Sustitucion de los valores 9999... por NaN (sabemos que la fila 2 son todo valores nulos para cada variable)
    valores_null = dfr.iloc[2, 4:]
    for i in range(len(valores_null)):
        dfr.iloc[:,i+4] = dfr.iloc[:,i+4].replace(valores_null[i], np.nan)
    return dfr

def imputar_por_interpolacion(dfr):
    #Sustituye los valores NaN por valores aproximados mediante el metodo de interpolacion
    dfr = dfr.interpolate(method='linear', limit_direction='forward')
    return dfr

def imputar_por_KNND(dfr):
    #Este metodo es para imputar las filas que no se hayan podido imputar con interpolacion (primera fila)
    imputer = KNNImputer(n_neighbors=3, weights = 'distance')
    dfr[:] = imputer.fit_transform(dfr)
    return dfr

def normalizar_datos(dfr):
    #Dado un DataFrame, devuelve el DataFrame con valores normalizados
    x = dfr.values #returns a numpy array
    standard_scaler = preprocessing.StandardScaler()
    dfr[:] = standard_scaler.fit_transform(x)
    #dfr = pd.DataFrame(x_scaled)
    return dfr

def desnormalizar_datos(dfr):
    #Dado un DataFrame, devuelve el DataFrame con valores desnormalizados
    x = dfr.values
    standard_scaler = preprocessing.StandardScaler()
    dfr[:] = standard_scaler.inverse_transform(x)
    return dfr

def eliminar_gaps(dfr, n):
    #Eliminacion de filas donde alguna columna tiene N NaNs consecutivos
    for columna in range(dfr.shape[1]):
        mask = dfr.iloc[:,columna].notna()
        a = mask.ne(mask.shift()).cumsum()
        dfr = dfr[(a.groupby(a).transform('size') < n) | mask]
    return dfr

def NaN_consecutivos(dfr):
    #Obtencion del numero maximo de NaN consecutivos segun columna
    nans_consecutivos = []
    for columna in range(df.shape[1]):
        nan_columna = max(df.iloc[:,columna].isnull().astype(int).groupby(df.iloc[:,columna].notnull().astype(int).cumsum()).sum())
        nans_consecutivos.append(nan_columna)

    df_nans = pd.DataFrame(columns = ['Variable','Numero de nans consecutivos'])
    df_nans.iloc[:,0] = df.columns
    df_nans.iloc[:,1] = nans_consecutivos
    return df_nans

# %% [markdown]
# #1-Montamos Drive para poder acceder a los datos y los leemos

# %%
#Leemos los datos
#df = pd.read_csv('datos.csv', header=0)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/TFG_codigo/Prediccion_general/datos.csv', header=0)

# %%
df.describe()
# Out:
#                Year           Day  ...  Proton Density(n/cc)  Proton Temperature(K)
# count  2.749248e+06  2.749248e+06  ...          2.749248e+06           2.749248e+06
# mean   2.007570e+03  1.823232e+02  ...          8.551741e+01           8.825655e+05
# std    7.543063e+00  1.057835e+02  ...          2.689619e+02           2.686965e+06
# min    1.995000e+03  1.000000e+00  ...          3.000000e-02           1.564000e+03
# 25%    2.001000e+03  9.000000e+01  ...          3.400000e+00           3.523000e+04
# 50%    2.008000e+03  1.820000e+02  ...          5.400000e+00           7.144900e+04
# 75%    2.014000e+03  2.740000e+02  ...          9.280000e+00           1.453960e+05
# max    2.021000e+03  3.660000e+02  ...          9.999900e+02           9.999999e+06
#
# [8 rows x 11 columns]

# %%
df
# Out:
#          Year  Day  ...  Proton Density(n/cc)  Proton Temperature(K)
# 0        1995    1  ...             18.422649           17401.558702
# 1        1995    1  ...             18.460000           17347.000000
# 2        1995    1  ...             18.348000           17510.600000
# 3        1995    1  ...             18.236000           17674.200000
# 4        1995    1  ...             18.124000           17837.800000
# ...       ...  ...  ...                   ...                    ...
# 2749243  2021   49  ...              4.670000           58514.000000
# 2749244  2021   49  ...              4.400000           62883.000000
# 2749245  2021   49  ...              4.650000           58624.000000
# 2749246  2021   49  ...              4.810000           67353.000000
# 2749247  2021   49  ...              4.290000           47244.000000
#
# [2749248 rows x 11 columns]

# %%
int(0.8 * int(df.shape[0]))
# Out:
# 2199398

# %%
df.shape[0] - 2199398
# Out:
# 549850

# %% [markdown]
# #2-Preprocesamos los datos y los normalizamos

# %%
df = sustituir(df)
df = imputar_por_interpolacion(df)
imputar_por_KNND(df.iloc[:3, :])
df = obtener_tiempo(df)
df = df.drop(['Year', 'Day', 'Hour', 'Minute'], axis = 1)
df = df.set_index('Datetime')
df = normalizar_datos(df)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8b139cf3d9f5> in <module>()
#       2 df = imputar_por_interpolacion(df)
#       3 imputar_por_KNND(df.iloc[:3, :])
# ----> 4 df = obtener_tiempo(df)
#       5 df = df.drop(['Year', 'Day', 'Hour', 'Minute'], axis = 1)
#       6 df = df.set_index('Datetime')
#
# <ipython-input-1-4b41b35955b4> in obtener_tiempo(dfr)
#      10 def obtener_tiempo(dfr):
#      11     #Esta funcion permite obtener una columna Datetime a partir del agno, dia, hora y minuto de los datos iniciales
# ---> 12     dfr['Day'] = pd.to_datetime(dfr['Day'], format='%j').dt.strftime('%m-%d')
#      13     dfr['Hour'] = dfr['Hour'].astype(str).str.zfill(2)
#      14     dfr['Datetime'] = pd.to_datetime(dfr[['Year','Day', 'Hour', 'Minute']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/accessor.py in f(self, *args, **kwargs)
#      97         def _create_delegator_method(name):
#      98             def f(self, *args, **kwargs):
# ---> 99                 return self._delegate_method(name, *args, **kwargs)
#     100
#     101             f.__name__ = name
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/accessors.py in _delegate_method(self, name, *args, **kwargs)
#     102
#     103         method = getattr(values, name)
# --> 104         result = method(*args, **kwargs)
#     105
#     106         if not is_list_like(result):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/extension.py in method(self, *args, **kwargs)
#      76
#      77         def method(self, *args, **kwargs):
# ---> 78             result = attr(self._data, *args, **kwargs)
#      79             if wrap:
#      80                 if isinstance(result, type(self._data)):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimelike.py in strftime(self, date_format)
#     267               dtype='object')
#     268         """
# --> 269         result = self._format_native_types(date_format=date_format, na_rep=np.nan)
#     270         return result.astype(object)
#     271
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py in _format_native_types(self, na_rep, date_format, **kwargs)
#     609
#     610         return tslib.format_array_from_datetime(
# --> 611             self.asi8.ravel(), tz=self.tz, format=fmt, na_rep=na_rep
#     612         ).reshape(self.shape)
#     613
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.format_array_from_datetime()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# KeyboardInterrupt:

# %% [markdown]
# #3-Creacion de datasets

# %%
#===================================Parametros para obtener train_dataset y val_dataset====================================
TRAIN_SPLIT   = int(0.8 * int(df.shape[0]))
STEP          = 1
past_history  = 18
future_target = 4
BUFFER_SIZE   = 10000

#===================================PARAMETROS DE ENTRENAMIENTO====================================
LEARNING_RATE = 0.001       #Learning rate es la tasa de aprendizaje (mirar word para mas detalle)
EPOCHS        = 20          #Determina el numero de iteraciones que ser realizan sobre los datos de entrenamiento
PATIENCE      = 5
#EVALUATION_INTERVAL = 200
BATCH_SIZE    = 256
DROPOUT_LSTM  = 0.15

def multivariate_multioutput_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data)[:,:,:,np.newaxis,np.newaxis], np.array(labels)[:,:,:,np.newaxis,np.newaxis]

#Creacion de datasets de entrenamiento y validacion
dataset = df.values

x_train_multi, y_train_multi = multivariate_multioutput_data(dataset, dataset, 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_multioutput_data(dataset, dataset,
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# #4-Creacion de modelos

# %% [markdown]
# **MODELO BASELINE**

# %%
def baseline(x_val, y_val):
  num_predicciones = len(y_val)
  timesteps_futuros = len(y_val[0])
  timesteps_pasados = len(x_val[0])
  variables = len(x_val[0][0])
  predicciones = np.zeros(shape=(y_val.shape))
  for prediccion in range(num_predicciones):
      dato = x_val[prediccion][timesteps_pasados-1]
      for num_timesteps_a_predecir in range(timesteps_futuros):
          predicciones[prediccion][num_timesteps_a_predecir] = dato
  return predicciones

# %% [markdown]
# **MODELO COMPLEJO**

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
def build_model_complejo(input_timesteps, output_timesteps, num_links, num_inputs):    
    model = Sequential()
    model.add(BatchNormalization(name = 'batch_norm_0', input_shape = (input_timesteps, num_inputs, 1, 1)))
    model.add(ConvLSTM2D(name ='conv_lstm_1',
                         filters = 64, kernel_size = (10, 1),                       
                         padding = 'same', 
                         return_sequences = True))
    
    model.add(Dropout(0.30, name = 'dropout_1'))
    model.add(BatchNormalization(name = 'batch_norm_1'))

    model.add(ConvLSTM2D(name ='conv_lstm_2',
                         filters = 64, kernel_size = (5, 1), 
                         padding='same',
                         return_sequences = False))
    
    model.add(Dropout(0.20, name = 'dropout_2'))
    model.add(BatchNormalization(name = 'batch_norm_2'))
    
    model.add(Flatten())
    model.add(RepeatVector(output_timesteps))
    model.add(Reshape((output_timesteps, num_inputs, 1, 64)))
    
    model.add(ConvLSTM2D(name ='conv_lstm_3',
                         filters = 64, kernel_size = (10, 1), 
                         padding='same',
                         return_sequences = True))
    
    model.add(Dropout(0.20, name = 'dropout_3'))
    model.add(BatchNormalization(name = 'batch_norm_3'))
    
    model.add(ConvLSTM2D(name ='conv_lstm_4',
                         filters = 64, kernel_size = (5, 1), 
                         padding='same',
                         return_sequences = True))
    
    model.add(TimeDistributed(Dense(units=1, name = 'dense_1', activation = 'relu')))
    model.add(Dense(units=1, name = 'dense_2', activation = 'linear'))
    
    optimizer = tf.keras.optimizers.RMSprop(lr=0.004, clipvalue=1.0)
    model.compile(loss = "mse", optimizer = optimizer, metrics = ['mae', 'mse'])
    return model

# %% [markdown]
# #5-Entrenamineto del modelo

# %%
import time
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
EPOCHS = 150
steps_per_epoch = 350
validation_steps = 500

path_checkpoint = "/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5"
modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)


modelstart = time.time()
early_stopping = EarlyStopping(monitor='val_loss', patience = 50, restore_best_weights=True)
model = build_model_complejo(x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2])
print(model.summary())

# Train
print("\nTRAIN MODEL...")
history = model.fit(train_data_multi,
                    epochs = EPOCHS,
                    validation_data=val_data_multi,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    verbose=1,
                    callbacks=[early_stopping, modelckpt_callback])

model.save('/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo.h5')
import pickle
with open('/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_history', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
print("\nModel Runtime: %0.2f Minutes"%((time.time() - modelstart)/60))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_norm_0 (BatchNormaliza (None, 18, 7, 1, 1)       4
# _________________________________________________________________
# conv_lstm_1 (ConvLSTM2D)     (None, 18, 7, 1, 64)      166656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 7, 1, 64)      0
# _________________________________________________________________
# batch_norm_1 (BatchNormaliza (None, 18, 7, 1, 64)      256
# _________________________________________________________________
# conv_lstm_2 (ConvLSTM2D)     (None, 7, 1, 64)          164096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 1, 64)          0
# _________________________________________________________________
# batch_norm_2 (BatchNormaliza (None, 7, 1, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 448)               0
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 448)            0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 7, 1, 64)       0
# _________________________________________________________________
# conv_lstm_3 (ConvLSTM2D)     (None, 4, 7, 1, 64)       327936
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 7, 1, 64)       0
# _________________________________________________________________
# batch_norm_3 (BatchNormaliza (None, 4, 7, 1, 64)       256
# _________________________________________________________________
# conv_lstm_4 (ConvLSTM2D)     (None, 4, 7, 1, 64)       164096
# _________________________________________________________________
# time_distributed (TimeDistri (None, 4, 7, 1, 1)        65
# _________________________________________________________________
# dense_2 (Dense)              (None, 4, 7, 1, 1)        2
# =================================================================
# Total params: 823,623
# Trainable params: 823,237
# Non-trainable params: 386
# _________________________________________________________________
# None
#
# TRAIN MODEL...
# Epoch 1/150
# 350/350 [==============================] - 130s 306ms/step - loss: 0.3081 - mae: 0.3604 - mse: 0.3081 - val_loss: 0.4781 - val_mae: 0.4923 - val_mse: 0.4781
#
# Epoch 00001: val_loss improved from inf to 0.47814, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 2/150
# 350/350 [==============================] - 106s 304ms/step - loss: 0.1141 - mae: 0.2107 - mse: 0.1141 - val_loss: 0.1711 - val_mae: 0.2453 - val_mse: 0.1711
#
# Epoch 00002: val_loss improved from 0.47814 to 0.17106, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 3/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1172 - mae: 0.2044 - mse: 0.1172 - val_loss: 0.1693 - val_mae: 0.2449 - val_mse: 0.1693
#
# Epoch 00003: val_loss improved from 0.17106 to 0.16932, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 4/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1452 - mae: 0.2204 - mse: 0.1452 - val_loss: 0.1404 - val_mae: 0.2147 - val_mse: 0.1404
#
# Epoch 00004: val_loss improved from 0.16932 to 0.14037, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 5/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1824 - mae: 0.2478 - mse: 0.1824 - val_loss: 0.1367 - val_mae: 0.2172 - val_mse: 0.1367
#
# Epoch 00005: val_loss improved from 0.14037 to 0.13673, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 6/150
# 350/350 [==============================] - 108s 307ms/step - loss: 0.1765 - mae: 0.2473 - mse: 0.1765 - val_loss: 0.1298 - val_mae: 0.2084 - val_mse: 0.1298
#
# Epoch 00006: val_loss improved from 0.13673 to 0.12979, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 7/150
# 350/350 [==============================] - 109s 311ms/step - loss: 0.2204 - mae: 0.2523 - mse: 0.2204 - val_loss: 0.2276 - val_mae: 0.3491 - val_mse: 0.2276
#
# Epoch 00007: val_loss did not improve from 0.12979
# Epoch 8/150
# 350/350 [==============================] - 107s 305ms/step - loss: 0.2015 - mae: 0.2393 - mse: 0.2015 - val_loss: 0.1397 - val_mae: 0.2229 - val_mse: 0.1397
#
# Epoch 00008: val_loss did not improve from 0.12979
# Epoch 9/150
# 350/350 [==============================] - 106s 303ms/step - loss: 0.1894 - mae: 0.2461 - mse: 0.1894 - val_loss: 0.1459 - val_mae: 0.2298 - val_mse: 0.1459
#
# Epoch 00009: val_loss did not improve from 0.12979
# Epoch 10/150
# 350/350 [==============================] - 106s 303ms/step - loss: 0.2064 - mae: 0.2807 - mse: 0.2064 - val_loss: 0.1513 - val_mae: 0.2523 - val_mse: 0.1513
#
# Epoch 00010: val_loss did not improve from 0.12979
# Epoch 11/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1932 - mae: 0.2600 - mse: 0.1932 - val_loss: 0.2458 - val_mae: 0.3539 - val_mse: 0.2458
#
# Epoch 00011: val_loss did not improve from 0.12979
# Epoch 12/150
# 350/350 [==============================] - 106s 304ms/step - loss: 0.2643 - mae: 0.2441 - mse: 0.2643 - val_loss: 0.1450 - val_mae: 0.2334 - val_mse: 0.1450
#
# Epoch 00012: val_loss did not improve from 0.12979
# Epoch 13/150
# 350/350 [==============================] - 107s 305ms/step - loss: 0.1723 - mae: 0.2286 - mse: 0.1723 - val_loss: 0.1424 - val_mae: 0.2255 - val_mse: 0.1424
#
# Epoch 00013: val_loss did not improve from 0.12979
# Epoch 14/150
# 350/350 [==============================] - 107s 306ms/step - loss: 0.1066 - mae: 0.1937 - mse: 0.1066 - val_loss: 0.1304 - val_mae: 0.2252 - val_mse: 0.1304
#
# Epoch 00014: val_loss did not improve from 0.12979
# Epoch 15/150
# 350/350 [==============================] - 107s 306ms/step - loss: 0.0964 - mae: 0.1856 - mse: 0.0964 - val_loss: 0.1230 - val_mae: 0.2003 - val_mse: 0.1230
#
# Epoch 00015: val_loss improved from 0.12979 to 0.12300, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 16/150
# 350/350 [==============================] - 106s 304ms/step - loss: 0.0845 - mae: 0.1797 - mse: 0.0845 - val_loss: 0.1661 - val_mae: 0.2804 - val_mse: 0.1661
#
# Epoch 00016: val_loss did not improve from 0.12300
# Epoch 17/150
# 350/350 [==============================] - 106s 303ms/step - loss: 0.0605 - mae: 0.1477 - mse: 0.0605 - val_loss: 0.1247 - val_mae: 0.1992 - val_mse: 0.1247
#
# Epoch 00017: val_loss did not improve from 0.12300
# Epoch 18/150
# 350/350 [==============================] - 106s 304ms/step - loss: 0.0583 - mae: 0.1447 - mse: 0.0583 - val_loss: 0.1314 - val_mae: 0.2145 - val_mse: 0.1314
#
# Epoch 00018: val_loss did not improve from 0.12300
# Epoch 19/150
# 350/350 [==============================] - 106s 304ms/step - loss: 0.0803 - mae: 0.1658 - mse: 0.0803 - val_loss: 0.1387 - val_mae: 0.2308 - val_mse: 0.1387
#
# Epoch 00019: val_loss did not improve from 0.12300
# Epoch 20/150
# 350/350 [==============================] - 106s 303ms/step - loss: 0.1076 - mae: 0.1840 - mse: 0.1076 - val_loss: 0.1205 - val_mae: 0.1976 - val_mse: 0.1205
#
# Epoch 00020: val_loss improved from 0.12300 to 0.12052, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 21/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1178 - mae: 0.1917 - mse: 0.1178 - val_loss: 0.1475 - val_mae: 0.2538 - val_mse: 0.1475
#
# Epoch 00021: val_loss did not improve from 0.12052
# Epoch 22/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.0900 - mae: 0.1737 - mse: 0.0900 - val_loss: 0.1276 - val_mae: 0.2084 - val_mse: 0.1276
#
# Epoch 00022: val_loss did not improve from 0.12052
# Epoch 23/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0894 - mae: 0.1710 - mse: 0.0894 - val_loss: 0.1559 - val_mae: 0.2535 - val_mse: 0.1559
#
# Epoch 00023: val_loss did not improve from 0.12052
# Epoch 24/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1404 - mae: 0.2150 - mse: 0.1404 - val_loss: 0.1273 - val_mae: 0.2189 - val_mse: 0.1273
#
# Epoch 00024: val_loss did not improve from 0.12052
# Epoch 25/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1405 - mae: 0.2153 - mse: 0.1405 - val_loss: 0.1157 - val_mae: 0.1928 - val_mse: 0.1157
#
# Epoch 00025: val_loss improved from 0.12052 to 0.11571, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 26/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1088 - mae: 0.1952 - mse: 0.1088 - val_loss: 0.1391 - val_mae: 0.2362 - val_mse: 0.1391
#
# Epoch 00026: val_loss did not improve from 0.11571
# Epoch 27/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0983 - mae: 0.1889 - mse: 0.0983 - val_loss: 0.1242 - val_mae: 0.2024 - val_mse: 0.1242
#
# Epoch 00027: val_loss did not improve from 0.11571
# Epoch 28/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0975 - mae: 0.1814 - mse: 0.0975 - val_loss: 0.1194 - val_mae: 0.1929 - val_mse: 0.1194
#
# Epoch 00028: val_loss did not improve from 0.11571
# Epoch 29/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1471 - mae: 0.2184 - mse: 0.1471 - val_loss: 0.1420 - val_mae: 0.2335 - val_mse: 0.1420
#
# Epoch 00029: val_loss did not improve from 0.11571
# Epoch 30/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1432 - mae: 0.2206 - mse: 0.1432 - val_loss: 0.1218 - val_mae: 0.2063 - val_mse: 0.1218
#
# Epoch 00030: val_loss did not improve from 0.11571
# Epoch 31/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1747 - mae: 0.2412 - mse: 0.1747 - val_loss: 0.1167 - val_mae: 0.1937 - val_mse: 0.1167
#
# Epoch 00031: val_loss did not improve from 0.11571
# Epoch 32/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1942 - mae: 0.2272 - mse: 0.1942 - val_loss: 0.1259 - val_mae: 0.2233 - val_mse: 0.1259
#
# Epoch 00032: val_loss did not improve from 0.11571
# Epoch 33/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1751 - mae: 0.2302 - mse: 0.1751 - val_loss: 0.1210 - val_mae: 0.2136 - val_mse: 0.1210
#
# Epoch 00033: val_loss did not improve from 0.11571
# Epoch 34/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1778 - mae: 0.2456 - mse: 0.1778 - val_loss: 0.1461 - val_mae: 0.2688 - val_mse: 0.1461
#
# Epoch 00034: val_loss did not improve from 0.11571
# Epoch 35/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.2018 - mae: 0.2696 - mse: 0.2018 - val_loss: 0.1199 - val_mae: 0.2051 - val_mse: 0.1199
#
# Epoch 00035: val_loss did not improve from 0.11571
# Epoch 36/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1483 - mae: 0.2218 - mse: 0.1483 - val_loss: 0.1415 - val_mae: 0.2395 - val_mse: 0.1415
#
# Epoch 00036: val_loss did not improve from 0.11571
# Epoch 37/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.2462 - mae: 0.2449 - mse: 0.2462 - val_loss: 0.1514 - val_mae: 0.2571 - val_mse: 0.1514
#
# Epoch 00037: val_loss did not improve from 0.11571
# Epoch 38/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1169 - mae: 0.1980 - mse: 0.1169 - val_loss: 0.1249 - val_mae: 0.2135 - val_mse: 0.1249
#
# Epoch 00038: val_loss did not improve from 0.11571
# Epoch 39/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1047 - mae: 0.1890 - mse: 0.1047 - val_loss: 0.1332 - val_mae: 0.2388 - val_mse: 0.1332
#
# Epoch 00039: val_loss did not improve from 0.11571
# Epoch 40/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0861 - mae: 0.1763 - mse: 0.0861 - val_loss: 0.1155 - val_mae: 0.1925 - val_mse: 0.1155
#
# Epoch 00040: val_loss improved from 0.11571 to 0.11545, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 41/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0711 - mae: 0.1613 - mse: 0.0711 - val_loss: 0.1237 - val_mae: 0.2080 - val_mse: 0.1237
#
# Epoch 00041: val_loss did not improve from 0.11545
# Epoch 42/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0540 - mae: 0.1380 - mse: 0.0540 - val_loss: 0.1208 - val_mae: 0.1957 - val_mse: 0.1208
#
# Epoch 00042: val_loss did not improve from 0.11545
# Epoch 43/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0660 - mae: 0.1529 - mse: 0.0660 - val_loss: 0.1200 - val_mae: 0.1978 - val_mse: 0.1200
#
# Epoch 00043: val_loss did not improve from 0.11545
# Epoch 44/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0939 - mae: 0.1736 - mse: 0.0939 - val_loss: 0.1227 - val_mae: 0.2074 - val_mse: 0.1227
#
# Epoch 00044: val_loss did not improve from 0.11545
# Epoch 45/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1131 - mae: 0.1854 - mse: 0.1131 - val_loss: 0.1150 - val_mae: 0.1891 - val_mse: 0.1150
#
# Epoch 00045: val_loss improved from 0.11545 to 0.11497, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 46/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0932 - mae: 0.1734 - mse: 0.0932 - val_loss: 0.1300 - val_mae: 0.2180 - val_mse: 0.1300
#
# Epoch 00046: val_loss did not improve from 0.11497
# Epoch 47/150
# 350/350 [==============================] - 106s 304ms/step - loss: 0.0928 - mae: 0.1722 - mse: 0.0928 - val_loss: 0.1194 - val_mae: 0.2094 - val_mse: 0.1194
#
# Epoch 00047: val_loss did not improve from 0.11497
# Epoch 48/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1003 - mae: 0.1842 - mse: 0.1003 - val_loss: 0.1364 - val_mae: 0.2264 - val_mse: 0.1364
#
# Epoch 00048: val_loss did not improve from 0.11497
# Epoch 49/150
# 350/350 [==============================] - 105s 302ms/step - loss: 0.1467 - mae: 0.2133 - mse: 0.1467 - val_loss: 0.1160 - val_mae: 0.1969 - val_mse: 0.1160
#
# Epoch 00049: val_loss did not improve from 0.11497
# Epoch 50/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1239 - mae: 0.2065 - mse: 0.1239 - val_loss: 0.1279 - val_mae: 0.2158 - val_mse: 0.1279
#
# Epoch 00050: val_loss did not improve from 0.11497
# Epoch 51/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0956 - mae: 0.1844 - mse: 0.0956 - val_loss: 0.1215 - val_mae: 0.2109 - val_mse: 0.1215
#
# Epoch 00051: val_loss did not improve from 0.11497
# Epoch 52/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0996 - mae: 0.1855 - mse: 0.0996 - val_loss: 0.1220 - val_mae: 0.2089 - val_mse: 0.1220
#
# Epoch 00052: val_loss did not improve from 0.11497
# Epoch 53/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1102 - mae: 0.1909 - mse: 0.1102 - val_loss: 0.1193 - val_mae: 0.2005 - val_mse: 0.1193
#
# Epoch 00053: val_loss did not improve from 0.11497
# Epoch 54/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1514 - mae: 0.2241 - mse: 0.1514 - val_loss: 0.1235 - val_mae: 0.2215 - val_mse: 0.1235
#
# Epoch 00054: val_loss did not improve from 0.11497
# Epoch 55/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1497 - mae: 0.2244 - mse: 0.1497 - val_loss: 0.1274 - val_mae: 0.2155 - val_mse: 0.1274
#
# Epoch 00055: val_loss did not improve from 0.11497
# Epoch 56/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1809 - mae: 0.2319 - mse: 0.1809 - val_loss: 0.1777 - val_mae: 0.2977 - val_mse: 0.1777
#
# Epoch 00056: val_loss did not improve from 0.11497
# Epoch 57/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1683 - mae: 0.2175 - mse: 0.1683 - val_loss: 0.1712 - val_mae: 0.2712 - val_mse: 0.1712
#
# Epoch 00057: val_loss did not improve from 0.11497
# Epoch 58/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1732 - mae: 0.2280 - mse: 0.1732 - val_loss: 0.1420 - val_mae: 0.2520 - val_mse: 0.1420
#
# Epoch 00058: val_loss did not improve from 0.11497
# Epoch 59/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1897 - mae: 0.2620 - mse: 0.1897 - val_loss: 0.1635 - val_mae: 0.2512 - val_mse: 0.1635
#
# Epoch 00059: val_loss did not improve from 0.11497
# Epoch 60/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1852 - mae: 0.2530 - mse: 0.1852 - val_loss: 0.2091 - val_mae: 0.3165 - val_mse: 0.2091
#
# Epoch 00060: val_loss did not improve from 0.11497
# Epoch 61/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.2292 - mae: 0.2288 - mse: 0.2292 - val_loss: 0.1215 - val_mae: 0.2031 - val_mse: 0.1215
#
# Epoch 00061: val_loss did not improve from 0.11497
# Epoch 62/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1679 - mae: 0.2218 - mse: 0.1679 - val_loss: 0.1443 - val_mae: 0.2653 - val_mse: 0.1443
#
# Epoch 00062: val_loss did not improve from 0.11497
# Epoch 63/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0992 - mae: 0.1838 - mse: 0.0992 - val_loss: 0.1902 - val_mae: 0.3099 - val_mse: 0.1902
#
# Epoch 00063: val_loss did not improve from 0.11497
# Epoch 64/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0961 - mae: 0.1809 - mse: 0.0961 - val_loss: 0.1240 - val_mae: 0.2188 - val_mse: 0.1240
#
# Epoch 00064: val_loss did not improve from 0.11497
# Epoch 65/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0818 - mae: 0.1748 - mse: 0.0818 - val_loss: 0.1147 - val_mae: 0.1912 - val_mse: 0.1147
#
# Epoch 00065: val_loss improved from 0.11497 to 0.11473, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 66/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0597 - mae: 0.1457 - mse: 0.0597 - val_loss: 0.1406 - val_mae: 0.2472 - val_mse: 0.1406
#
# Epoch 00066: val_loss did not improve from 0.11473
# Epoch 67/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0550 - mae: 0.1397 - mse: 0.0550 - val_loss: 0.1400 - val_mae: 0.2228 - val_mse: 0.1400
#
# Epoch 00067: val_loss did not improve from 0.11473
# Epoch 68/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0747 - mae: 0.1589 - mse: 0.0747 - val_loss: 0.1184 - val_mae: 0.2041 - val_mse: 0.1184
#
# Epoch 00068: val_loss did not improve from 0.11473
# Epoch 69/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1022 - mae: 0.1780 - mse: 0.1022 - val_loss: 0.1630 - val_mae: 0.2750 - val_mse: 0.1630
#
# Epoch 00069: val_loss did not improve from 0.11473
# Epoch 70/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1128 - mae: 0.1863 - mse: 0.1128 - val_loss: 0.1353 - val_mae: 0.2408 - val_mse: 0.1353
#
# Epoch 00070: val_loss did not improve from 0.11473
# Epoch 71/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0855 - mae: 0.1690 - mse: 0.0855 - val_loss: 0.1527 - val_mae: 0.2678 - val_mse: 0.1527
#
# Epoch 00071: val_loss did not improve from 0.11473
# Epoch 72/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0888 - mae: 0.1663 - mse: 0.0888 - val_loss: 0.1249 - val_mae: 0.2175 - val_mse: 0.1249
#
# Epoch 00072: val_loss did not improve from 0.11473
# Epoch 73/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1223 - mae: 0.2028 - mse: 0.1223 - val_loss: 0.1180 - val_mae: 0.2063 - val_mse: 0.1180
#
# Epoch 00073: val_loss did not improve from 0.11473
# Epoch 74/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1437 - mae: 0.2118 - mse: 0.1437 - val_loss: 0.1192 - val_mae: 0.2024 - val_mse: 0.1192
#
# Epoch 00074: val_loss did not improve from 0.11473
# Epoch 75/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1088 - mae: 0.1929 - mse: 0.1088 - val_loss: 0.1342 - val_mae: 0.2458 - val_mse: 0.1342
#
# Epoch 00075: val_loss did not improve from 0.11473
# Epoch 76/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.0955 - mae: 0.1854 - mse: 0.0955 - val_loss: 0.1172 - val_mae: 0.2006 - val_mse: 0.1172
#
# Epoch 00076: val_loss did not improve from 0.11473
# Epoch 77/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0952 - mae: 0.1785 - mse: 0.0952 - val_loss: 0.1178 - val_mae: 0.1921 - val_mse: 0.1178
#
# Epoch 00077: val_loss did not improve from 0.11473
# Epoch 78/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1363 - mae: 0.2087 - mse: 0.1363 - val_loss: 0.1322 - val_mae: 0.2163 - val_mse: 0.1322
#
# Epoch 00078: val_loss did not improve from 0.11473
# Epoch 79/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.1381 - mae: 0.2153 - mse: 0.1381 - val_loss: 0.1856 - val_mae: 0.2972 - val_mse: 0.1856
#
# Epoch 00079: val_loss did not improve from 0.11473
# Epoch 80/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.1664 - mae: 0.2340 - mse: 0.1664 - val_loss: 0.1116 - val_mae: 0.1872 - val_mse: 0.1116
#
# Epoch 00080: val_loss improved from 0.11473 to 0.11161, saving model to /content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_weights.h5
# Epoch 81/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1867 - mae: 0.2238 - mse: 0.1867 - val_loss: 0.1640 - val_mae: 0.2693 - val_mse: 0.1640
#
# Epoch 00081: val_loss did not improve from 0.11161
# Epoch 82/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1734 - mae: 0.2249 - mse: 0.1734 - val_loss: 0.1337 - val_mae: 0.2354 - val_mse: 0.1337
#
# Epoch 00082: val_loss did not improve from 0.11161
# Epoch 83/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1704 - mae: 0.2377 - mse: 0.1704 - val_loss: 0.1246 - val_mae: 0.2252 - val_mse: 0.1246
#
# Epoch 00083: val_loss did not improve from 0.11161
# Epoch 84/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.1914 - mae: 0.2648 - mse: 0.1914 - val_loss: 0.1781 - val_mae: 0.2753 - val_mse: 0.1781
#
# Epoch 00084: val_loss did not improve from 0.11161
# Epoch 85/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1630 - mae: 0.2271 - mse: 0.1630 - val_loss: 0.1377 - val_mae: 0.2323 - val_mse: 0.1377
#
# Epoch 00085: val_loss did not improve from 0.11161
# Epoch 86/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.2700 - mae: 0.2457 - mse: 0.2700 - val_loss: 0.1184 - val_mae: 0.2101 - val_mse: 0.1184
#
# Epoch 00086: val_loss did not improve from 0.11161
# Epoch 87/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1288 - mae: 0.2030 - mse: 0.1288 - val_loss: 0.1404 - val_mae: 0.2525 - val_mse: 0.1404
#
# Epoch 00087: val_loss did not improve from 0.11161
# Epoch 88/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1020 - mae: 0.1855 - mse: 0.1020 - val_loss: 0.1305 - val_mae: 0.2209 - val_mse: 0.1305
#
# Epoch 00088: val_loss did not improve from 0.11161
# Epoch 89/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.0850 - mae: 0.1721 - mse: 0.0850 - val_loss: 0.1766 - val_mae: 0.3145 - val_mse: 0.1766
#
# Epoch 00089: val_loss did not improve from 0.11161
# Epoch 90/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.0737 - mae: 0.1637 - mse: 0.0737 - val_loss: 0.1251 - val_mae: 0.2130 - val_mse: 0.1251
#
# Epoch 00090: val_loss did not improve from 0.11161
# Epoch 91/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.0542 - mae: 0.1378 - mse: 0.0542 - val_loss: 0.1194 - val_mae: 0.2014 - val_mse: 0.1194
#
# Epoch 00091: val_loss did not improve from 0.11161
# Epoch 92/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.0631 - mae: 0.1480 - mse: 0.0631 - val_loss: 0.1216 - val_mae: 0.2084 - val_mse: 0.1216
#
# Epoch 00092: val_loss did not improve from 0.11161
# Epoch 93/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.0874 - mae: 0.1686 - mse: 0.0874 - val_loss: 0.1559 - val_mae: 0.2864 - val_mse: 0.1559
#
# Epoch 00093: val_loss did not improve from 0.11161
# Epoch 94/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1123 - mae: 0.1838 - mse: 0.1123 - val_loss: 0.1712 - val_mae: 0.3036 - val_mse: 0.1712
#
# Epoch 00094: val_loss did not improve from 0.11161
# Epoch 95/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0936 - mae: 0.1729 - mse: 0.0936 - val_loss: 0.1141 - val_mae: 0.1930 - val_mse: 0.1141
#
# Epoch 00095: val_loss did not improve from 0.11161
# Epoch 96/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0898 - mae: 0.1692 - mse: 0.0898 - val_loss: 0.1297 - val_mae: 0.2214 - val_mse: 0.1297
#
# Epoch 00096: val_loss did not improve from 0.11161
# Epoch 97/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0929 - mae: 0.1765 - mse: 0.0929 - val_loss: 0.1229 - val_mae: 0.2092 - val_mse: 0.1229
#
# Epoch 00097: val_loss did not improve from 0.11161
# Epoch 98/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1460 - mae: 0.2130 - mse: 0.1460 - val_loss: 0.1752 - val_mae: 0.3043 - val_mse: 0.1752
#
# Epoch 00098: val_loss did not improve from 0.11161
# Epoch 99/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1235 - mae: 0.2051 - mse: 0.1235 - val_loss: 0.1374 - val_mae: 0.2356 - val_mse: 0.1374
#
# Epoch 00099: val_loss did not improve from 0.11161
# Epoch 100/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0973 - mae: 0.1845 - mse: 0.0973 - val_loss: 0.1156 - val_mae: 0.1907 - val_mse: 0.1156
#
# Epoch 00100: val_loss did not improve from 0.11161
# Epoch 101/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.0995 - mae: 0.1852 - mse: 0.0995 - val_loss: 0.1207 - val_mae: 0.2118 - val_mse: 0.1207
#
# Epoch 00101: val_loss did not improve from 0.11161
# Epoch 102/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0999 - mae: 0.1827 - mse: 0.0999 - val_loss: 0.1438 - val_mae: 0.2502 - val_mse: 0.1438
#
# Epoch 00102: val_loss did not improve from 0.11161
# Epoch 103/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.1523 - mae: 0.2221 - mse: 0.1523 - val_loss: 0.1338 - val_mae: 0.2344 - val_mse: 0.1338
#
# Epoch 00103: val_loss did not improve from 0.11161
# Epoch 104/150
# 350/350 [==============================] - 104s 299ms/step - loss: 0.1463 - mae: 0.2215 - mse: 0.1463 - val_loss: 0.1258 - val_mae: 0.2213 - val_mse: 0.1258
#
# Epoch 00104: val_loss did not improve from 0.11161
# Epoch 105/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.1698 - mae: 0.2289 - mse: 0.1698 - val_loss: 0.1737 - val_mae: 0.2998 - val_mse: 0.1737
#
# Epoch 00105: val_loss did not improve from 0.11161
# Epoch 106/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.1703 - mae: 0.2179 - mse: 0.1703 - val_loss: 0.1146 - val_mae: 0.1948 - val_mse: 0.1146
#
# Epoch 00106: val_loss did not improve from 0.11161
# Epoch 107/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1769 - mae: 0.2285 - mse: 0.1769 - val_loss: 0.1291 - val_mae: 0.2221 - val_mse: 0.1291
#
# Epoch 00107: val_loss did not improve from 0.11161
# Epoch 108/150
# 350/350 [==============================] - 104s 299ms/step - loss: 0.1820 - mae: 0.2555 - mse: 0.1820 - val_loss: 0.1703 - val_mae: 0.2763 - val_mse: 0.1703
#
# Epoch 00108: val_loss did not improve from 0.11161
# Epoch 109/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1917 - mae: 0.2585 - mse: 0.1917 - val_loss: 0.1393 - val_mae: 0.2470 - val_mse: 0.1393
#
# Epoch 00109: val_loss did not improve from 0.11161
# Epoch 110/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.1878 - mae: 0.2228 - mse: 0.1878 - val_loss: 0.2603 - val_mae: 0.3774 - val_mse: 0.2603
#
# Epoch 00110: val_loss did not improve from 0.11161
# Epoch 111/150
# 350/350 [==============================] - 106s 302ms/step - loss: 0.1731 - mae: 0.2261 - mse: 0.1731 - val_loss: 0.1146 - val_mae: 0.1957 - val_mse: 0.1146
#
# Epoch 00111: val_loss did not improve from 0.11161
# Epoch 112/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1101 - mae: 0.1998 - mse: 0.1101 - val_loss: 0.1230 - val_mae: 0.2151 - val_mse: 0.1230
#
# Epoch 00112: val_loss did not improve from 0.11161
# Epoch 113/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1075 - mae: 0.1992 - mse: 0.1075 - val_loss: 0.1246 - val_mae: 0.2177 - val_mse: 0.1246
#
# Epoch 00113: val_loss did not improve from 0.11161
# Epoch 114/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0842 - mae: 0.1773 - mse: 0.0842 - val_loss: 0.1417 - val_mae: 0.2597 - val_mse: 0.1417
#
# Epoch 00114: val_loss did not improve from 0.11161
# Epoch 115/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0617 - mae: 0.1479 - mse: 0.0617 - val_loss: 0.1306 - val_mae: 0.2255 - val_mse: 0.1306
#
# Epoch 00115: val_loss did not improve from 0.11161
# Epoch 116/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.0519 - mae: 0.1359 - mse: 0.0519 - val_loss: 0.1164 - val_mae: 0.1941 - val_mse: 0.1164
#
# Epoch 00116: val_loss did not improve from 0.11161
# Epoch 117/150
# 350/350 [==============================] - 105s 301ms/step - loss: 0.0725 - mae: 0.1600 - mse: 0.0725 - val_loss: 0.1241 - val_mae: 0.2173 - val_mse: 0.1241
#
# Epoch 00117: val_loss did not improve from 0.11161
# Epoch 118/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1069 - mae: 0.1812 - mse: 0.1069 - val_loss: 0.1882 - val_mae: 0.3358 - val_mse: 0.1882
#
# Epoch 00118: val_loss did not improve from 0.11161
# Epoch 119/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1152 - mae: 0.1908 - mse: 0.1152 - val_loss: 0.1239 - val_mae: 0.2073 - val_mse: 0.1239
#
# Epoch 00119: val_loss did not improve from 0.11161
# Epoch 120/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.0864 - mae: 0.1687 - mse: 0.0864 - val_loss: 0.1173 - val_mae: 0.2002 - val_mse: 0.1173
#
# Epoch 00120: val_loss did not improve from 0.11161
# Epoch 121/150
# 350/350 [==============================] - 104s 299ms/step - loss: 0.0882 - mae: 0.1661 - mse: 0.0882 - val_loss: 0.1164 - val_mae: 0.1943 - val_mse: 0.1164
#
# Epoch 00121: val_loss did not improve from 0.11161
# Epoch 122/150
# 350/350 [==============================] - 104s 299ms/step - loss: 0.1188 - mae: 0.1995 - mse: 0.1188 - val_loss: 0.1364 - val_mae: 0.2526 - val_mse: 0.1364
#
# Epoch 00122: val_loss did not improve from 0.11161
# Epoch 123/150
# 350/350 [==============================] - 105s 300ms/step - loss: 0.1411 - mae: 0.2107 - mse: 0.1411 - val_loss: 0.1178 - val_mae: 0.2036 - val_mse: 0.1178
#
# Epoch 00123: val_loss did not improve from 0.11161
# Epoch 124/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1128 - mae: 0.1954 - mse: 0.1128 - val_loss: 0.1358 - val_mae: 0.2432 - val_mse: 0.1358
#
# Epoch 00124: val_loss did not improve from 0.11161
# Epoch 125/150
# 350/350 [==============================] - 105s 299ms/step - loss: 0.0961 - mae: 0.1866 - mse: 0.0961 - val_loss: 0.1415 - val_mae: 0.2328 - val_mse: 0.1415
#
# Epoch 00125: val_loss did not improve from 0.11161
# Epoch 126/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.0930 - mae: 0.1772 - mse: 0.0930 - val_loss: 0.1346 - val_mae: 0.2446 - val_mse: 0.1346
#
# Epoch 00126: val_loss did not improve from 0.11161
# Epoch 127/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1318 - mae: 0.2055 - mse: 0.1318 - val_loss: 0.1164 - val_mae: 0.2096 - val_mse: 0.1164
#
# Epoch 00127: val_loss did not improve from 0.11161
# Epoch 128/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1374 - mae: 0.2155 - mse: 0.1374 - val_loss: 0.1473 - val_mae: 0.2583 - val_mse: 0.1473
#
# Epoch 00128: val_loss did not improve from 0.11161
# Epoch 129/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1596 - mae: 0.2300 - mse: 0.1596 - val_loss: 0.1272 - val_mae: 0.2271 - val_mse: 0.1272
#
# Epoch 00129: val_loss did not improve from 0.11161
# Epoch 130/150
# 350/350 [==============================] - 104s 298ms/step - loss: 0.1757 - mae: 0.2207 - mse: 0.1757 - val_loss: 0.2643 - val_mae: 0.3563 - val_mse: 0.2643
#
# Epoch 00130: val_loss did not improve from 0.11161
#
# Model Runtime: 228.54 Minutes

# %% [markdown]
# #6-Evaluación del modelo

# %% [markdown]
# **Realizamos predicciones con el modelo entrenado y con el modelo baseline, las guardamos y las cargamos**

# %%
predicciones = model.predict(x_val_multi, verbose=1)
predicciones_baseline = baseline(x_val_multi, y_val_multi)

np.save('/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_predicciones', predicciones)
np.save('/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/predicciones_baseline', predicciones_baseline)
# Out:
# 17183/17183 [==============================] - 560s 33ms/step

# %%
predicciones_c        = np.load('/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/modelo_complejo_predicciones.npy')
predicciones_baseline = np.load('/content/drive/MyDrive/TFG_codigo/Prediccion_general/Modelos_2horasPasado/predicciones_baseline.npy')

# %% [markdown]
# Generamos la estructura para que con las funciones podamos obtener las métricas de cada modelo para compararlos

# %%
predicciones = [predicciones_c, predicciones_baseline]
nombre_modelos = ['Complejo', 'Baseline']
variables = df.columns

# %%
variables = variables[4:]

# %%
variables
# Out:
# Index(['IMF(nT)', 'Bx GSM(nT)', 'By GSM(nT)', 'Bz GSM(nT)', 'Flow Speed(km/s)',
#        'Proton Density(n/cc)', 'Proton Temperature(K)'],
#       dtype='object')

# %% [markdown]
# **Generamos las comparativas entre los modelos**

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
def obtener_metricas(y_val, y_preds, nombre_modelos):
    #Aplanamos los datos para que se puedan calcular las metricas
    y_val = np.squeeze(y_val)
    y_val = y_val.ravel()
    datos_mse  = []
    datos_r2   = []
    datos_rmse = []
    datos_mae  = []
    columnas   = []
    for modelo in range(len(nombre_modelos)):
        y_pred = np.squeeze(y_preds[modelo])
        y_pred = y_pred.ravel()
        #Calculamos las metricas
        r2   = r2_score(y_val, y_pred)
        mse  = mean_squared_error(y_val, y_pred)
        mae  = mean_absolute_error(y_val, y_pred)
        rmse = mse**0.5
        #Los anadimos a las listas correspondientes
        datos_mse.append(mse)
        datos_r2.append(r2)
        datos_rmse.append(rmse)
        datos_mae.append(mae)
        #Creamos una columna por modelo
        columnas.append(nombre_modelos[modelo])

    #Mostramos los resultados en forma de df
    nombres_metricas = ['R2', 'RMSE', 'MSE', 'MAE']
    valores = [datos_r2, datos_rmse, datos_mse, datos_mae]

    metricas = pd.DataFrame(valores, columns = columnas, index = nombres_metricas)
    return metricas



def desglose_por_timestep(y_val, predicciones):
    num_predicciones = predicciones.shape[0]
    num_timesteps   = predicciones.shape[1]

    timesteps_y_val  = []
    timesteps_y_pred = []
    
    #Creamos 4 listas, una para cada timestep
    for lista_timestep in range(num_timesteps):
        timestep_valN = []
        timesteps_y_val.append(timestep_valN)
        timestep_predN = []
        timesteps_y_pred.append(timestep_predN)
    #Metemos en cada una de los 4 listas, el correspondiente timestep de cada prediccion
    for prediccion in range(num_predicciones):
        for timestep in range(num_timesteps):
            timesteps_y_pred[timestep].append(predicciones[prediccion][timestep])
            timesteps_y_val[timestep].append(y_val[prediccion][timestep])
    
    return timesteps_y_val, timesteps_y_pred

def comparacion_modelos_timestep(y_val, predicciones, nombre_modelos):
  timesteps_y_preds = []
  for modelo in range(len(nombre_modelos)):
      timesteps_y_val, timesteps_y_pred_modelo = desglose_por_timestep(y_val, predicciones[modelo])
      timesteps_y_preds.append(timesteps_y_pred_modelo)
  for timestep in range(4):
      timesteps_modelos = []
      for modelo in range(len(nombre_modelos)):
          timesteps_modelos.append(timesteps_y_preds[modelo][timestep])
      print("=========TIMESTEP: ",timestep,"=========\n",obtener_metricas(timesteps_y_val[timestep], timesteps_modelos, nombre_modelos))


def comparacion_modelos_timestep_variables(y_val, predicciones, nombre_modelos, nombre_variables):
  desglose_preds = []
  for modelo in range(len(nombre_modelos)):
      desglose_val, desglose_pred = agrupar_variables_timestep(y_val, predicciones[modelo])
      desglose_preds.append(desglose_pred)
  
  for paso in range(4):
    print("===================TIMESTEP ", paso,"===================")
    for variable in range(len(nombre_variables)):
        variableN_modelos = []
        for modelo in range(len(nombre_modelos)):
          variableN_modelos.append(desglose_preds[modelo][paso][variable])
        print("=====VARIABLE", nombre_variables[variable],"====")
        print(obtener_metricas(desglose_val[paso][variable], variableN_modelos, nombre_modelos))


def agrupar_variables_timestep(y_val, y_pred):
    num_predicciones = y_val.shape[0]
    num_timesteps    = y_val.shape[1]
    num_variables    = y_val.shape[2]
    #Creacion de listas
    desglose_val  = []
    desglose_pred = []
    for paso in range(num_timesteps):
        timestepN_val  = []
        timestepN_pred = []
        for i in range(num_variables):
            timestepN_varI_val = []
            timestepN_val.append(timestepN_varI_val)
            
            timestepN_varI_pred = []
            timestepN_pred.append(timestepN_varI_pred)
            
        desglose_val.append(timestepN_val)
        desglose_pred.append(timestepN_pred)
    
    #Desglose
    for prediccion in range(num_predicciones):
        for paso in range(num_timesteps):
            for var in range(num_variables):
                desglose_val[paso][var].append(y_val[prediccion][paso][var])
                desglose_pred[paso][var].append(y_pred[prediccion][paso][var])
    
    return desglose_val, desglose_pred




def resumen_comparativa(y_val, predicciones, nombre_modelos, variables):
    pd.set_option("display.max_rows", None, "display.max_columns", None)

    #1-Comparativa general de los modelos
    print("===================================================COMPARATIVA GENERAL DE LOS MODELOS===================================================")
    print(obtener_metricas(y_val, predicciones, nombre_modelos))

    #2-Comparativa por timestep de los modelos
    print("===================================================COMPARATIVA POR TIMESTEP DE LOS MODELOS===================================================")
    print(comparacion_modelos_timestep(y_val, predicciones, nombre_modelos))

    print("===================================================COMPARATIVA POR TIMESTEP Y VARIABLES DE LOS MODELOS===================================================")
    #3-Comparativa por timestep y variable de los modelos
    print(comparacion_modelos_timestep_variables(y_val, predicciones, nombre_modelos, variables))

# %%
resumen_comparativa(y_val_multi, predicciones, nombre_modelos, variables)
# Out:
# ===================================================COMPARATIVA GENERAL DE LOS MODELOS===================================================
#       Complejo  Baseline
# R2    0.888201  0.881893
# RMSE  0.292120  0.300248
# MSE   0.085334  0.090149
# MAE   0.161063  0.150333
# ===================================================COMPARATIVA POR TIMESTEP DE LOS MODELOS===================================================
# =========TIMESTEP:  0 =========
#        Complejo  Baseline
# R2    0.943110  0.948454
# RMSE  0.208384  0.198356
# MSE   0.043424  0.039345
# MAE   0.115311  0.097533
# =========TIMESTEP:  1 =========
#        Complejo  Baseline
# R2    0.899649  0.897183
# RMSE  0.276761  0.280141
# MSE   0.076596  0.078479
# MAE   0.153703  0.141391
# =========TIMESTEP:  2 =========
#        Complejo  Baseline
# R2    0.867839  0.857743
# RMSE  0.317608  0.329517
# MSE   0.100875  0.108582
# MAE   0.178455  0.170097
# =========TIMESTEP:  3 =========
#        Complejo  Baseline
# R2    0.842205  0.824191
# RMSE  0.347044  0.366319
# MSE   0.120440  0.134189
# MAE   0.196783  0.192312
# None
# ===================================================COMPARATIVA POR TIMESTEP Y VARIABLES DE LOS MODELOS===================================================
# ===================TIMESTEP  0 ===================
# =====VARIABLE IMF(nT) ====
#       Complejo  Baseline
# R2    0.973521  0.980511
# RMSE  0.127172  0.109103
# MSE   0.016173  0.011903
# MAE   0.080386  0.057721
# =====VARIABLE Bx GSM(nT) ====
#       Complejo  Baseline
# R2    0.933097  0.934998
# RMSE  0.229718  0.226431
# MSE   0.052770  0.051271
# MAE   0.145363  0.130825
# =====VARIABLE By GSM(nT) ====
#       Complejo  Baseline
# R2    0.921483  0.923091
# RMSE  0.235947  0.233519
# MSE   0.055671  0.054531
# MAE   0.144392  0.131612
# =====VARIABLE Bz GSM(nT) ====
#       Complejo  Baseline
# R2    0.850309  0.852552
# RMSE  0.315824  0.313449
# MSE   0.099745  0.098251
# MAE   0.189196  0.175709
# =====VARIABLE Flow Speed(km/s) ====
#       Complejo  Baseline
# R2    0.992429  0.996715
# RMSE  0.081615  0.053758
# MSE   0.006661  0.002890
# MAE   0.059878  0.030566
# =====VARIABLE Proton Density(n/cc) ====
#       Complejo  Baseline
# R2    0.972044  0.977795
# RMSE  0.158738  0.141470
# MSE   0.025198  0.020014
# MAE   0.086133  0.066901
# =====VARIABLE Proton Temperature(K) ====
#       Complejo  Baseline
# R2    0.935195  0.950390
# RMSE  0.218520  0.191193
# MSE   0.047751  0.036555
# MAE   0.101829  0.089397
# ===================TIMESTEP  1 ===================
# =====VARIABLE IMF(nT) ====
#       Complejo  Baseline
# R2    0.953915  0.959285
# RMSE  0.167771  0.157692
# MSE   0.028147  0.024867
# MAE   0.105567  0.086809
# =====VARIABLE Bx GSM(nT) ====
#       Complejo  Baseline
# R2    0.871697  0.864585
# RMSE  0.318119  0.326817
# MSE   0.101200  0.106810
# MAE   0.204427  0.195726
# =====VARIABLE By GSM(nT) ====
#       Complejo  Baseline
# R2    0.850695  0.840063
# RMSE  0.325365  0.336750
# MSE   0.105862  0.113401
# MAE   0.203630  0.196519
# =====VARIABLE Bz GSM(nT) ====
#       Complejo  Baseline
# R2    0.720545  0.697490
# RMSE  0.431516  0.448963
# MSE   0.186206  0.201568
# MAE   0.266602  0.261216
# =====VARIABLE Flow Speed(km/s) ====
#       Complejo  Baseline
# R2    0.990267  0.994125
# RMSE  0.092535  0.071896
# MSE   0.008563  0.005169
# MAE   0.066713  0.042729
# =====VARIABLE Proton Density(n/cc) ====
#       Complejo  Baseline
# R2    0.952495  0.956773
# RMSE  0.206920  0.197385
# MSE   0.042816  0.038961
# MAE   0.107018  0.091729
# =====VARIABLE Proton Temperature(K) ====
#       Complejo  Baseline
# R2    0.913983  0.920501
# RMSE  0.251755  0.242029
# MSE   0.063381  0.058578
# MAE   0.121964  0.115010
# ===================TIMESTEP  2 ===================
# =====VARIABLE IMF(nT) ====
#       Complejo  Baseline
# R2    0.938507  0.941884
# RMSE  0.193795  0.188399
# MSE   0.037557  0.035494
# MAE   0.121124  0.106540
# =====VARIABLE Bx GSM(nT) ====
#       Complejo  Baseline
# R2    0.824772  0.809208
# RMSE  0.371770  0.387929
# MSE   0.138213  0.150489
# MAE   0.245122  0.238685
# =====VARIABLE By GSM(nT) ====
#       Complejo  Baseline
# R2    0.799859  0.776456
# RMSE  0.376704  0.398120
# MSE   0.141906  0.158500
# MAE   0.239991  0.238649
# =====VARIABLE Bz GSM(nT) ====
#       Complejo  Baseline
# R2    0.629894  0.580172
# RMSE  0.496590  0.528896
# MSE   0.246601  0.279731
# MAE   0.315876  0.316863
# =====VARIABLE Flow Speed(km/s) ====
#       Complejo  Baseline
# R2    0.988337  0.992103
# RMSE  0.101294  0.083353
# MSE   0.010260  0.006948
# MAE   0.072798  0.050761
# =====VARIABLE Proton Density(n/cc) ====
#       Complejo  Baseline
# R2    0.935325  0.937533
# RMSE  0.241431  0.237274
# MSE   0.058289  0.056299
# MAE   0.121814  0.108937
# =====VARIABLE Proton Temperature(K) ====
#       Complejo  Baseline
# R2    0.900522  0.901456
# RMSE  0.270739  0.269464
# MSE   0.073299  0.072611
# MAE   0.132461  0.130243
# ===================TIMESTEP  3 ===================
# =====VARIABLE IMF(nT) ====
#       Complejo  Baseline
# R2    0.924965  0.926284
# RMSE  0.214072  0.212183
# MSE   0.045827  0.045022
# MAE   0.133997  0.122253
# =====VARIABLE Bx GSM(nT) ====
#       Complejo  Baseline
# R2    0.787116  0.762226
# RMSE  0.409774  0.433067
# MSE   0.167915  0.187547
# MAE   0.273499  0.271887
# =====VARIABLE By GSM(nT) ====
#       Complejo  Baseline
# R2    0.759461  0.724126
# RMSE  0.412977  0.442271
# MSE   0.170550  0.195603
# MAE   0.266836  0.270574
# =====VARIABLE Bz GSM(nT) ====
#       Complejo  Baseline
# R2    0.561382  0.483750
# RMSE  0.540594  0.586486
# MSE   0.292242  0.343966
# MAE   0.349975  0.358960
# =====VARIABLE Flow Speed(km/s) ====
#       Complejo  Baseline
# R2    0.986784  0.990359
# RMSE  0.107830  0.092097
# MSE   0.011627  0.008482
# MAE   0.077417  0.057135
# =====VARIABLE Proton Density(n/cc) ====
#       Complejo  Baseline
# R2    0.919025  0.919017
# RMSE  0.270140  0.270153
# MSE   0.072976  0.072982
# MAE   0.134042  0.123320
# =====VARIABLE Proton Temperature(K) ====
#       Complejo  Baseline
# R2    0.888793  0.883662
# RMSE  0.286255  0.292784
# MSE   0.081942  0.085722
# MAE   0.141713  0.142053
# None
